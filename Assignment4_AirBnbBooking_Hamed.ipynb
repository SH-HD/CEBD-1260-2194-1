# %% [markdown]
# # Hamed Shariffar Assignment 4
# CEBD 1260 Introduction to machine learning
# Session 4 : Feature engineering - Hotel Booking

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline    
import seaborn as sns
import glob

# %%
#define your data path or specify your path, please modify your path accordingly on your own system
DATA_PATH = r'C:\Users\Hamed\OneDrive - Concordia University - Canada\1260\Class_Materials\project_data\hotel_booking\new-user-bookings'
file_name = os.path.join(DATA_PATH,'train_users_2.csv')
print(file_name)

# %%
DATA_PATH = r'C:\Users\Hamed\OneDrive - Concordia University - Canada\1260\Class_Materials\project_data\hotel_booking\new-user-bookings'
all_files = glob.glob(DATA_PATH+r"\*.csv")
all_files
# Out:
# ['C:\\Users\\Hamed\\OneDrive - Concordia University - Canada\\1260\\Class_Materials\\project_data\\hotel_booking\\new-user-bookings\\age_gender_bkts.csv',
#  'C:\\Users\\Hamed\\OneDrive - Concordia University - Canada\\1260\\Class_Materials\\project_data\\hotel_booking\\new-user-bookings\\countries.csv',
#  'C:\\Users\\Hamed\\OneDrive - Concordia University - Canada\\1260\\Class_Materials\\project_data\\hotel_booking\\new-user-bookings\\sessions.csv',
#  'C:\\Users\\Hamed\\OneDrive - Concordia University - Canada\\1260\\Class_Materials\\project_data\\hotel_booking\\new-user-bookings\\train_users_2.csv']

# %% [markdown]
# # 4.1 main table: train_users_2.csv

# %%
train_df = pd.read_csv(all_files[3])

# %%
print(train_df.shape)
train_df.head()
# Out:
# (213451, 16)
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
train_df['age'] = train_df['age'].astype(np.float16)
print(train_df.columns.values)
# Out:
# ['id' 'date_account_created' 'timestamp_first_active' 'date_first_booking'
#  'gender' 'age' 'signup_method' 'signup_flow' 'language'
#  'affiliate_channel' 'affiliate_provider' 'first_affiliate_tracked'
#  'signup_app' 'first_device_type' 'first_browser' 'country_destination']

# %% [markdown]
# # assignment 1:
#  1. Handle "timestamp_first_active", it is real time stamp, but you need to split them by writting a simple script
#
#  2. from time stamp you just created from 1, extract more information on year, month, week, weekday,......

# %%
#1. Handle "timestamp_first_active", it is real time stamp, but you need to split them by writting a simple script
# Change Dates to consistent format
print("Fixing timestamps...")
train_df['date_account_created'] = pd.to_datetime(train_df['date_account_created'], format='%Y-%m-%d')
train_df['timestamp_first_active'] = pd.to_datetime(train_df['timestamp_first_active'], format='%Y%m%d%H%M%S')
#main_df['date_account_created'].fillna(main_df.timestamp_first_active, inplace=True)
train_df.head()
# Out:
# Fixing timestamps...
#            id date_account_created timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaN
# 1  820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaN
# 2  4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# 3  bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 4  87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
# 2. from time stamp you just created from 1, extract more information on year, month, week, weekday,......
train_df['First_Active_year'],train_df['First_Active_month']= train_df.timestamp_first_active.dt.year,train_df.timestamp_first_active.dt.month
train_df['First_Active_day'],train_df['First_Active_Week'] = train_df.timestamp_first_active.dt.day,train_df.timestamp_first_active.dt.week
train_df['First_Active_Hour'],train_df['First_Active_Min']= train_df.timestamp_first_active.dt.hour,train_df.timestamp_first_active.dt.minute
train_df['First_Active_Sec'],train_df['First_Active_DayOfWeek'] = train_df.timestamp_first_active.dt.second,train_df.timestamp_first_active.dt.weekday
train_df['First_Active_Sec'],train_df['First_Active_DayName'] = train_df.timestamp_first_active.dt.second,train_df.timestamp_first_active.dt.weekday_name
train_df['First_Active_Sec'],train_df['First_Active_DayYear'] = train_df.timestamp_first_active.dt.second,train_df.timestamp_first_active.dt.year
train_df
# Out:
#                 id date_account_created timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-28    2009-03-19 04:32:55
# 1       820tgsjxq7           2011-05-25    2009-05-23 17:48:09
# 2       4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47
# 3       bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29
# 4       87mebub9p4           2010-09-14    2009-12-08 06:11:05
# ...            ...                  ...                    ...
# 213446  zxodksqpep           2014-06-30    2014-06-30 23:56:36
# 213447  mhewnxesx9           2014-06-30    2014-06-30 23:57:19
# 213448  6o3arsjbb4           2014-06-30    2014-06-30 23:57:54
# 213449  jh95kwisub           2014-06-30    2014-06-30 23:58:22
# 213450  nw9fwlyb5f           2014-06-30    2014-06-30 23:58:24
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# 1                     NaN       MALE  38.0      facebook            0
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213446                NaN       MALE  32.0         basic            0
# 213447                NaN  -unknown-   NaN         basic            0
# 213448                NaN  -unknown-  32.0         basic            0
# 213449                NaN  -unknown-   NaN         basic           25
# 213450                NaN  -unknown-   NaN         basic           25
#
#        language affiliate_channel  ... First_Active_year First_Active_month  \
# 0            en            direct  ...              2009                  3
# 1            en               seo  ...              2009                  5
# 2            en            direct  ...              2009                  6
# 3            en            direct  ...              2009                 10
# 4            en            direct  ...              2009                 12
# ...         ...               ...  ...               ...                ...
# 213446       en         sem-brand  ...              2014                  6
# 213447       en            direct  ...              2014                  6
# 213448       en            direct  ...              2014                  6
# 213449       en             other  ...              2014                  6
# 213450       en            direct  ...              2014                  6
#
#        First_Active_day First_Active_Week First_Active_Hour First_Active_Min  \
# 0                    19                12                 4               32
# 1                    23                21                17               48
# 2                     9                24                23               12
# 3                    31                44                 6                1
# 4                     8                50                 6               11
# ...                 ...               ...               ...              ...
# 213446               30                27                23               56
# 213447               30                27                23               57
# 213448               30                27                23               57
# 213449               30                27                23               58
# 213450               30                27                23               58
#
#         First_Active_Sec  First_Active_DayOfWeek  First_Active_DayName  \
# 0                     55                       3              Thursday
# 1                      9                       5              Saturday
# 2                     47                       1               Tuesday
# 3                     29                       5              Saturday
# 4                      5                       1               Tuesday
# ...                  ...                     ...                   ...
# 213446                36                       0                Monday
# 213447                19                       0                Monday
# 213448                54                       0                Monday
# 213449                22                       0                Monday
# 213450                24                       0                Monday
#
#         First_Active_DayYear
# 0                       2009
# 1                       2009
# 2                       2009
# 3                       2009
# 4                       2009
# ...                      ...
# 213446                  2014
# 213447                  2014
# 213448                  2014
# 213449                  2014
# 213450                  2014
#
# [213451 rows x 26 columns]

# %% [markdown]
# # 4.2 session.csv
# This file shows the the detail activities from each user, these can be aggregated and then merged into the main table

# %%
session_df = pd.read_csv(all_files[2])

# %%
session_df.head()
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %% [markdown]
# # Assignment 2: complete feature engineering for this table
#
# This file is not too hard, the main focus should be secs_elased, because it can indicate something
# (1) the mean value of it can indicate how much time each user spend on viewing the information online
# (2) the action_type indicates if the user just click or put order on items
# Once you complete all feature engineer for each files and clean the data, you can merge them into the main table by User ID

# %%
session_df = session_df.rename(columns={"user_id": "id"})
session_df.head()
# Out:
#            id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %%
session_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
# id               object
# action           object
# action_type      object
# action_detail    object
# device_type      object
# secs_elapsed     float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %%
session_df['secs_elapsed'] = session_df['secs_elapsed'].astype(np.float32)
session_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
# id               object
# action           object
# action_type      object
# action_detail    object
# device_type      object
# secs_elapsed     float32
# dtypes: float32(1), object(5)
# memory usage: 443.4+ MB

# %%
session_df['action'].describe()
# Out:
# count     10488111
# unique         359
# top           show
# freq       2768278
# Name: action, dtype: object

# %%
session_df['device_type'].unique()
# Out:
# array(['Windows Desktop', '-unknown-', 'Mac Desktop', 'Android Phone',
#        'iPhone', 'iPad Tablet', 'Android App Unknown Phone/Tablet',
#        'Linux Desktop', 'Tablet', 'Chromebook', 'Blackberry', 'iPodtouch',
#        'Windows Phone', 'Opera Phone'], dtype=object)

# %%
#This will give number of NaN values in every column.
session_df.isnull().sum(axis = 0)
# Out:
# id                 34496
# action             79626
# action_type      1126204
# action_detail    1126204
# device_type            0
# secs_elapsed      136031
# dtype: int64
